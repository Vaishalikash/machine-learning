# %%
import pandas as pd

# %%
#read the CSV file 
df = pd.read_csv('gapminder.csv') # df is the table which is called data frame 
df.head(5) # prints the first five rows
# Out:
#        country continent  year  lifeExp  population   gdpPerCap
# 0  Afghanistan      Asia  1952   28.801     8425333  779.445314
# 1  Afghanistan      Asia  1957   30.332     9240934  820.853030
# 2  Afghanistan      Asia  1962   31.997    10267083  853.100710
# 3  Afghanistan      Asia  1967   34.020    11537966  836.197138
# 4  Afghanistan      Asia  1972   36.088    13079460  739.981106

# %%
df.tail(5) # prints the last five row
# Out:
#        country continent  year  lifeExp  population   gdpPerCap
# 1699  Zimbabwe    Africa  1987   62.351     9216418  706.157306
# 1700  Zimbabwe    Africa  1992   60.377    10704340  693.420786
# 1701  Zimbabwe    Africa  1997   46.809    11404948  792.449960
# 1702  Zimbabwe    Africa  2002   39.989    11926563  672.038623
# 1703  Zimbabwe    Africa  2007   43.487    12311143  469.709298

# %%
type(df) # check the dataframe type
# Out:
# pandas.core.frame.DataFrame

# %%
df.shape # gives the dimention of the dataframe
# Out:
# (1704, 6)

# %%
df.info() # gives the basic information of the data frame
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1704 entries, 0 to 1703
# Data columns (total 6 columns):
# country       1704 non-null object
# continent     1704 non-null object
# year          1704 non-null int64
# lifeExp       1704 non-null float64
# population    1704 non-null int64
# gdpPerCap     1704 non-null float64
# dtypes: float64(2), int64(2), object(2)
# memory usage: 80.0+ KB

# %%
#statistical overview of the dataframe
df.describe()
# Out:
#              year      lifeExp    population      gdpPerCap
# count  1704.00000  1704.000000  1.704000e+03    1704.000000
# mean   1979.50000    59.474439  2.960121e+07    7215.327081
# std      17.26533    12.917107  1.061579e+08    9857.454543
# min    1952.00000    23.599000  6.001100e+04     241.165877
# 25%    1965.75000    48.198000  2.793664e+06    1202.060309
# 50%    1979.50000    60.712500  7.023596e+06    3531.846989
# 75%    1993.25000    70.845500  1.958522e+07    9325.462346
# max    2007.00000    82.603000  1.318683e+09  113523.132900

# %%
df.columns # gives the columns name
# Out:
# Index(['country', 'continent', 'year', 'lifeExp', 'population', 'gdpPerCap'], dtype='object')

# %%
df.keys() # also gives columns name
# Out:
# Index(['country', 'continent', 'year', 'lifeExp', 'population', 'gdpPerCap'], dtype='object')

# %%
df['country'] # access the columns values
# Out:
# 0       Afghanistan
# 1       Afghanistan
# 2       Afghanistan
# 3       Afghanistan
# 4       Afghanistan
# 5       Afghanistan
# 6       Afghanistan
# 7       Afghanistan
# 8       Afghanistan
# 9       Afghanistan
# 10      Afghanistan
# 11      Afghanistan
# 12          Albania
# 13          Albania
# 14          Albania
# 15          Albania
# 16          Albania
# 17          Albania
# 18          Albania
# 19          Albania
# 20          Albania
# 21          Albania
# 22          Albania
# 23          Albania
# 24          Algeria
# 25          Algeria
# 26          Algeria
# 27          Algeria
# 28          Algeria
# 29          Algeria
#            ...
# 1674    Yemen, Rep.
# 1675    Yemen, Rep.
# 1676    Yemen, Rep.
# 1677    Yemen, Rep.
# 1678    Yemen, Rep.
# 1679    Yemen, Rep.
# 1680         Zambia
# 1681         Zambia
# 1682         Zambia
# 1683         Zambia
# 1684         Zambia
# 1685         Zambia
# 1686         Zambia
# 1687         Zambia
# ...

# %%
#access the multiple value of multiple colomns
df[['country' , 'lifeExp']]
# Out:
#           country  lifeExp
# 0     Afghanistan   28.801
# 1     Afghanistan   30.332
# 2     Afghanistan   31.997
# 3     Afghanistan   34.020
# 4     Afghanistan   36.088
# 5     Afghanistan   38.438
# 6     Afghanistan   39.854
# 7     Afghanistan   40.822
# 8     Afghanistan   41.674
# 9     Afghanistan   41.763
# 10    Afghanistan   42.129
# 11    Afghanistan   43.828
# 12        Albania   55.230
# 13        Albania   59.280
# 14        Albania   64.820
# 15        Albania   66.220
# 16        Albania   67.690
# 17        Albania   68.930
# 18        Albania   70.420
# 19        Albania   72.000
# 20        Albania   71.581
# 21        Albania   72.950
# 22        Albania   75.651
# 23        Albania   76.423
# 24        Algeria   43.077
# 25        Algeria   45.685
# 26        Algeria   48.303
# 27        Algeria   51.407
# 28        Algeria   54.518
# 29        Algeria   58.014
# ...           ...      ...
# 1674  Yemen, Rep.   49.113
# 1675  Yemen, Rep.   52.922
# ...

# %%
df.columns[0]
# Out:
# 'country'

# %%
# to change the name of the columns
df.rename(columns ={"country" : "COUNTRY"} , inplace = True)

# %%
df.columns
# Out:
# Index(['COUNTRY', 'continent', 'year', 'lifeExp', 'population', 'gdpPerCap'], dtype='object')

# %%
df.index[[2,3]]
# Out:
# Int64Index([2, 3], dtype='int64')

# %%
df.drop(labels = "continent" , axis = 1 )
# Out:
#           COUNTRY  year  lifeExp  population    gdpPerCap
# 0     Afghanistan  1952   28.801     8425333   779.445314
# 1     Afghanistan  1957   30.332     9240934   820.853030
# 2     Afghanistan  1962   31.997    10267083   853.100710
# 3     Afghanistan  1967   34.020    11537966   836.197138
# 4     Afghanistan  1972   36.088    13079460   739.981106
# 5     Afghanistan  1977   38.438    14880372   786.113360
# 6     Afghanistan  1982   39.854    12881816   978.011439
# 7     Afghanistan  1987   40.822    13867957   852.395945
# 8     Afghanistan  1992   41.674    16317921   649.341395
# 9     Afghanistan  1997   41.763    22227415   635.341351
# 10    Afghanistan  2002   42.129    25268405   726.734055
# 11    Afghanistan  2007   43.828    31889923   974.580338
# 12        Albania  1952   55.230     1282697  1601.056136
# 13        Albania  1957   59.280     1476505  1942.284244
# 14        Albania  1962   64.820     1728137  2312.888958
# ...

# %%
df.drop( df.index[[2,3]]) # to drop some rows
# Out:
#           COUNTRY continent  year  lifeExp  population    gdpPerCap
# 0     Afghanistan      Asia  1952   28.801     8425333   779.445314
# 1     Afghanistan      Asia  1957   30.332     9240934   820.853030
# 4     Afghanistan      Asia  1972   36.088    13079460   739.981106
# 5     Afghanistan      Asia  1977   38.438    14880372   786.113360
# 6     Afghanistan      Asia  1982   39.854    12881816   978.011439
# 7     Afghanistan      Asia  1987   40.822    13867957   852.395945
# 8     Afghanistan      Asia  1992   41.674    16317921   649.341395
# 9     Afghanistan      Asia  1997   41.763    22227415   635.341351
# 10    Afghanistan      Asia  2002   42.129    25268405   726.734055
# 11    Afghanistan      Asia  2007   43.828    31889923   974.580338
# 12        Albania    Europe  1952   55.230     1282697  1601.056136
# 13        Albania    Europe  1957   59.280     1476505  1942.284244
# 14        Albania    Europe  1962   64.820     1728137  2312.888958
# ...

# %%
df.iloc[700] # gives the row at index number 700 , iloc works with indexes and loc work with lables
# Out:
# COUNTRY           India
# continent          Asia
# year               1972
# lifeExp          50.651
# population    567000000
# gdpPerCap       724.033
# Name: 700, dtype: object

# %%
df.iloc[[0,10,100]] # we always have to pass it as a list if we are accessing multiple rows or colomns
# Out:
#          COUNTRY continent  year  lifeExp  population   gdpPerCap
# 0    Afghanistan      Asia  1952   28.801     8425333  779.445314
# 10   Afghanistan      Asia  2002   42.129    25268405  726.734055
# 100   Bangladesh      Asia  1972   45.252    70759295  630.233627

# %%
df.iloc[-1] # gives the last row
# Out:
# COUNTRY       Zimbabwe
# continent       Africa
# year              2007
# lifeExp         43.487
# population    12311143
# gdpPerCap      469.709
# Name: 1703, dtype: object

# %%
# it does not work with labels
df.loc[-1]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\indexing.py in _validate_key(self, key, axis)
#    1789                 if not ax.contains(key):
# -> 1790                     error()
#    1791             except TypeError as e:
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\indexing.py in error()
#    1784                                .format(key=key,
# -> 1785                                        axis=self.obj._get_axis_name(axis)))
#    1786
#
# KeyError: 'the label [-1] is not in the [index]'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-26-c90b8b3cd7a5> in <module>
#       1 # it does not work with labels
# ----> 2 df.loc[-1]
#
# ...

# %%
df.iloc[1:20]
# Out:
#         COUNTRY continent  year  lifeExp  population    gdpPerCap
# 1   Afghanistan      Asia  1957   30.332     9240934   820.853030
# 2   Afghanistan      Asia  1962   31.997    10267083   853.100710
# 3   Afghanistan      Asia  1967   34.020    11537966   836.197138
# 4   Afghanistan      Asia  1972   36.088    13079460   739.981106
# 5   Afghanistan      Asia  1977   38.438    14880372   786.113360
# 6   Afghanistan      Asia  1982   39.854    12881816   978.011439
# 7   Afghanistan      Asia  1987   40.822    13867957   852.395945
# 8   Afghanistan      Asia  1992   41.674    16317921   649.341395
# 9   Afghanistan      Asia  1997   41.763    22227415   635.341351
# 10  Afghanistan      Asia  2002   42.129    25268405   726.734055
# 11  Afghanistan      Asia  2007   43.828    31889923   974.580338
# 12      Albania    Europe  1952   55.230     1282697  1601.056136
# 13      Albania    Europe  1957   59.280     1476505  1942.284244
# ...

# %%
df.loc[1:20] # invloves ending point also
# Out:
#         COUNTRY continent  year  lifeExp  population    gdpPerCap
# 1   Afghanistan      Asia  1957   30.332     9240934   820.853030
# 2   Afghanistan      Asia  1962   31.997    10267083   853.100710
# 3   Afghanistan      Asia  1967   34.020    11537966   836.197138
# 4   Afghanistan      Asia  1972   36.088    13079460   739.981106
# 5   Afghanistan      Asia  1977   38.438    14880372   786.113360
# 6   Afghanistan      Asia  1982   39.854    12881816   978.011439
# 7   Afghanistan      Asia  1987   40.822    13867957   852.395945
# 8   Afghanistan      Asia  1992   41.674    16317921   649.341395
# 9   Afghanistan      Asia  1997   41.763    22227415   635.341351
# 10  Afghanistan      Asia  2002   42.129    25268405   726.734055
# 11  Afghanistan      Asia  2007   43.828    31889923   974.580338
# 12      Albania    Europe  1952   55.230     1282697  1601.056136
# 13      Albania    Europe  1957   59.280     1476505  1942.284244
# ...

# %%
mixed splicing
df.iloc[1:5 , 1:4 ]
# Out:
#   continent  year  lifeExp
# 1      Asia  1957   30.332
# 2      Asia  1962   31.997
# 3      Asia  1967   34.020
# 4      Asia  1972   36.088

# %%
#df.loc[1:5 , 1:4] #wont work as columns name is not numeric or else we can do
df.loc[1:5 , ['continent' , 'country' , 'lifeExp']]
# Out:
# C:\Users\User\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\indexing.py:1472: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   return self._getitem_tuple(key)
#   continent  country  lifeExp
# 1      Asia      NaN   30.332
# 2      Asia      NaN   31.997
# 3      Asia      NaN   34.020
# 4      Asia      NaN   36.088
# 5      Asia      NaN   38.438

# %%
#series : single dimention list in panda ara called series
r = df.loc[0]
print(type(r)) # it will be series 
c = df['COUNTRY']
print(type(c))
# Out:
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>

# %%
le = df['lifeExp'] # this works ,'lifeExo ' is a key 
m = le.mean()
m
# Out:
# 59.47443936619713

# %%
le>58
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
# 5       False
# 6       False
# 7       False
# 8       False
# 9       False
# 10      False
# 11      False
# 12      False
# 13       True
# 14       True
# 15       True
# 16       True
# 17       True
# 18       True
# 19       True
# 20       True
# 21       True
# 22       True
# 23       True
# 24      False
# 25      False
# 26      False
# 27      False
# 28      False
# 29       True
#         ...
# 1674    False
# 1675    False
# 1676    False
# 1677     True
# 1678     True
# 1679     True
# 1680    False
# 1681    False
# 1682    False
# 1683    False
# 1684    False
# 1685    False
# 1686    False
# 1687    False
# 1688    False
# 1689    False
# 1690    False
# 1691    False
# 1692    False
# 1693    False
# 1694    False
# 1695    False
# 1696    False
# 1697    False
# 1698     True
# 1699     True
# 1700     True
# 1701    False
# 1702    False
# 1703    False
# ...

# %%
df.loc[df['lifeExp']>59] #retur ros with lieExp > 59
# Out:
#                  COUNTRY continent  year  lifeExp  population     gdpPerCap
# 13               Albania    Europe  1957   59.280     1476505   1942.284244
# 14               Albania    Europe  1962   64.820     1728137   2312.888958
# 15               Albania    Europe  1967   66.220     1984060   2760.196931
# 16               Albania    Europe  1972   67.690     2263554   3313.422188
# 17               Albania    Europe  1977   68.930     2509048   3533.003910
# 18               Albania    Europe  1982   70.420     2780097   3630.880722
# 19               Albania    Europe  1987   72.000     3075321   3738.932735
# 20               Albania    Europe  1992   71.581     3326498   2497.437901
# 21               Albania    Europe  1997   72.950     3428038   3193.054604
# 22               Albania    Europe  2002   75.651     3508512   4604.211737
# 23               Albania    Europe  2007   76.423     3600523   5937.029526
# ...

# %%
df.loc[df.lifeExp > m ,['COUNTRY' , 'lifeExp']] # return rows with lifExp greater then mean
# Out:
#                  COUNTRY  lifeExp
# 14               Albania   64.820
# 15               Albania   66.220
# 16               Albania   67.690
# 17               Albania   68.930
# 18               Albania   70.420
# 19               Albania   72.000
# 20               Albania   71.581
# 21               Albania   72.950
# 22               Albania   75.651
# 23               Albania   76.423
# 30               Algeria   61.368
# 31               Algeria   65.799
# 32               Algeria   67.744
# 33               Algeria   69.152
# 34               Algeria   70.994
# 35               Algeria   72.301
# 48             Argentina   62.485
# 49             Argentina   64.399
# 50             Argentina   65.142
# 51             Argentina   65.634
# 52             Argentina   67.065
# 53             Argentina   68.481
# 54             Argentina   69.942
# 55             Argentina   70.774
# 56             Argentina   71.868
# 57             Argentina   73.275
# ...

# %%
df.loc[(df.lifeExp < 60 )& (df.lifeExp <62)]
# Out:
#           COUNTRY continent  year  lifeExp  population    gdpPerCap
# 0     Afghanistan      Asia  1952   28.801     8425333   779.445314
# 1     Afghanistan      Asia  1957   30.332     9240934   820.853030
# 2     Afghanistan      Asia  1962   31.997    10267083   853.100710
# 3     Afghanistan      Asia  1967   34.020    11537966   836.197138
# 4     Afghanistan      Asia  1972   36.088    13079460   739.981106
# 5     Afghanistan      Asia  1977   38.438    14880372   786.113360
# 6     Afghanistan      Asia  1982   39.854    12881816   978.011439
# 7     Afghanistan      Asia  1987   40.822    13867957   852.395945
# 8     Afghanistan      Asia  1992   41.674    16317921   649.341395
# 9     Afghanistan      Asia  1997   41.763    22227415   635.341351
# 10    Afghanistan      Asia  2002   42.129    25268405   726.734055
# 11    Afghanistan      Asia  2007   43.828    31889923   974.580338
# 12        Albania    Europe  1952   55.230     1282697  1601.056136
# ...

# %%
df.loc[(df.lifeExp <30) | (df.lifeExp < 62 ) , ['year' , 'country']]
# Out:
#       year  country
# 0     1952      NaN
# 1     1957      NaN
# 2     1962      NaN
# 3     1967      NaN
# 4     1972      NaN
# 5     1977      NaN
# 6     1982      NaN
# 7     1987      NaN
# 8     1992      NaN
# 9     1997      NaN
# 10    2002      NaN
# 11    2007      NaN
# 12    1952      NaN
# 13    1957      NaN
# 24    1952      NaN
# 25    1957      NaN
# 26    1962      NaN
# 27    1967      NaN
# 28    1972      NaN
# 29    1977      NaN
# 30    1982      NaN
# 36    1952      NaN
# 37    1957      NaN
# 38    1962      NaN
# 39    1967      NaN
# 40    1972      NaN
# 41    1977      NaN
# 42    1982      NaN
# 43    1987      NaN
# 44    1992      NaN
# ...    ...      ...
# 1672  1972      NaN
# 1673  1977      NaN
# 1674  1982      NaN
# 1675  1987      NaN
# 1676  1992      NaN
# 1677  1997      NaN
# 1678  2002      NaN
# 1680  1952      NaN
# 1681  1957      NaN
# 1682  1962      NaN
# 1683  1967      NaN
# 1684  1972      NaN
# 1685  1977      NaN
# ...

# %%
df.loc[df.COUNTRY == "Zimbabwe"]
# Out:
#        COUNTRY continent  year  lifeExp  population   gdpPerCap
# 1692  Zimbabwe    Africa  1952   48.451     3080907  406.884115
# 1693  Zimbabwe    Africa  1957   50.469     3646340  518.764268
# 1694  Zimbabwe    Africa  1962   52.358     4277736  527.272182
# 1695  Zimbabwe    Africa  1967   53.995     4995432  569.795071
# 1696  Zimbabwe    Africa  1972   55.635     5861135  799.362176
# 1697  Zimbabwe    Africa  1977   57.674     6642107  685.587682
# 1698  Zimbabwe    Africa  1982   60.363     7636524  788.855041
# 1699  Zimbabwe    Africa  1987   62.351     9216418  706.157306
# 1700  Zimbabwe    Africa  1992   60.377    10704340  693.420786
# 1701  Zimbabwe    Africa  1997   46.809    11404948  792.449960
# 1702  Zimbabwe    Africa  2002   39.989    11926563  672.038623
# 1703  Zimbabwe    Africa  2007   43.487    12311143  469.709298

# %%
df.loc[(df.COUNTRY == "kenya") | (df.COUNTRY == "Egypt")]
# Out:
#     COUNTRY continent  year  lifeExp  population    gdpPerCap
# 456   Egypt    Africa  1952   41.893    22223309  1418.822445
# 457   Egypt    Africa  1957   44.444    25009741  1458.915272
# 458   Egypt    Africa  1962   46.992    28173309  1693.335853
# 459   Egypt    Africa  1967   49.293    31681188  1814.880728
# 460   Egypt    Africa  1972   51.137    34807417  2024.008147
# 461   Egypt    Africa  1977   53.319    38783863  2785.493582
# 462   Egypt    Africa  1982   56.006    45681811  3503.729636
# 463   Egypt    Africa  1987   59.797    52799062  3885.460710
# 464   Egypt    Africa  1992   63.674    59402198  3794.755195
# 465   Egypt    Africa  1997   67.217    66134291  4173.181797
# 466   Egypt    Africa  2002   69.806    73312559  4754.604414
# 467   Egypt    Africa  2007   71.338    80264543  5581.180998

# %%
df.loc[df.COUNTRY>"Nigeria"]
# Out:
#           COUNTRY continent  year  lifeExp  population     gdpPerCap
# 1140       Norway    Europe  1952   72.670     3327728  10095.421720
# 1141       Norway    Europe  1957   73.440     3491938  11653.973040
# 1142       Norway    Europe  1962   73.470     3638919  13450.401510
# 1143       Norway    Europe  1967   74.080     3786019  16361.876470
# 1144       Norway    Europe  1972   74.340     3933004  18965.055510
# 1145       Norway    Europe  1977   75.370     4043205  23311.349390
# 1146       Norway    Europe  1982   75.970     4114787  26298.635310
# 1147       Norway    Europe  1987   75.890     4186147  31540.974800
# 1148       Norway    Europe  1992   77.320     4286357  33965.661150
# 1149       Norway    Europe  1997   78.320     4405672  41283.164330
# 1150       Norway    Europe  2002   79.050     4535591  44683.975250
# 1151       Norway    Europe  2007   80.196     4627926  49357.190170
# 1152         Oman      Asia  1952   37.578      507833   1828.230307
# ...

# %%
# GROUPING
df.groupby('year')['lifeExp'].mean() # gives the mean for each group , can specify multiple columns here
# Out:
# year
# 1952    49.057620
# 1957    51.507401
# 1962    53.609249
# 1967    55.678290
# 1972    57.647386
# 1977    59.570157
# 1982    61.533197
# 1987    63.212613
# 1992    64.160338
# 1997    65.014676
# 2002    65.694923
# 2007    67.007423
# Name: lifeExp, dtype: float64

# %%
df.groupby('year')['gdpPerCap'].mean().reset_index()
# Out:
#     year     gdpPerCap
# 0   1952   3725.276046
# 1   1957   4299.408345
# 2   1962   4725.812342
# 3   1967   5483.653047
# 4   1972   6770.082815
# 5   1977   7313.166421
# 6   1982   7518.901673
# 7   1987   7900.920218
# 8   1992   8158.608521
# 9   1997   9090.175363
# 10  2002   9917.848365
# 11  2007  11680.071820

# %%
#sorting
df.sort_values(['year' , 'lifeExp'])
# Out:
#                        COUNTRY continent  year  lifeExp  population  \
# 0                  Afghanistan      Asia  1952   28.801     8425333
# 552                     Gambia    Africa  1952   30.000      284320
# 36                      Angola    Africa  1952   30.015     4232095
# 1344              Sierra Leone    Africa  1952   30.331     2143249
# 1032                Mozambique    Africa  1952   31.286     6446316
# 192               Burkina Faso    Africa  1952   31.975     4469979
# 624              Guinea-Bissau    Africa  1952   32.500      580653
# 1668               Yemen, Rep.      Asia  1952   32.548     4963829
# 1392                   Somalia    Africa  1952   32.978     2526994
# 612                     Guinea    Africa  1952   33.609     2664249
# 948                       Mali    Africa  1952   33.685     3838168
# 504                   Ethiopia    Africa  1952   34.078    20860941
# 480          Equatorial Guinea    Africa  1952   34.482      216964
# ...

# %%
df.sort_values(['year', 'lifeExp'], ascending=[True, False])
# Out:
#                        COUNTRY continent  year  lifeExp  population  \
# 1140                    Norway    Europe  1952   72.670     3327728
# 684                    Iceland    Europe  1952   72.490      147962
# 1080               Netherlands    Europe  1952   72.130    10381988
# 1464                    Sweden    Europe  1952   71.860     7124673
# 408                    Denmark    Europe  1952   70.780     4334000
# 1476               Switzerland    Europe  1952   69.620     4815000
# 1092               New Zealand   Oceania  1952   69.390     1994794
# 1596            United Kingdom    Europe  1952   69.180    50430000
# 60                   Australia   Oceania  1952   69.120     8691212
# 240                     Canada  Americas  1952   68.750    14785584
# 1608             United States  Americas  1952   68.440   157553000
# 108                    Belgium    Europe  1952   68.000     8730405
# 564                    Germany    Europe  1952   67.500    69145952
# ...

# %%
#create your own data
pd.Series([10,20,30])
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
pd.Series(['x', 'y', 'z'])
# Out:
# 0    x
# 1    y
# 2    z
# dtype: object

# %%
#create dataframe
pd.DataFrame([[10,20] , [30,40]] , columns=['A' , 'B']) #passing data list rows
# Out:
#     A   B
# 0  10  20
# 1  30  40

# %%
pd.DataFrame({'A':[10, 30], 'B':[20, 40]}) # give the data column-wise
# Out:
#     A   B
# 0  10  20
# 1  30  40

# %%
#concatenate the data
a = pd.DataFrame([[10, 20], [30, 40]], columns=['A', 'B'])
b = pd.DataFrame({'A':[50, 70], 'C':[60, 80]})
pd.concat([a, b])
#a warning because it can be probably detect that this is not what you intent to do.
# Out:
# C:\Users\User\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:4: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   after removing the cwd from sys.path.
#     A     B     C
# 0  10  20.0   NaN
# 1  30  40.0   NaN
# 0  50   NaN  60.0
# 1  70   NaN  80.0
